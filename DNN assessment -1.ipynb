# %% [markdown]
# # DNN Lab Assessment
# 1. Implement back propogation neural network using different activation functions and
# analysis the performance
# 2. Implement dropout and early stopping concept using any suitable dataset
# 3. Implement different optimization techniques using any suitable dataset and analysis
# their performance

# %%
import numpy as np

import pandas as pd 
import keras

from numpy import unique, argmax

from tensorflow.keras.datasets.mnist import load_data 

from tensorflow.keras import Sequential

from tensorflow.keras.layers import Conv2D

from tensorflow.keras.layers import MaxPool2D
import seaborn as sns 

from tensorflow.keras.layers import Dense 

from tensorflow.keras.layers import Flatten 

from tensorflow.keras.layers import Dropout 

from tensorflow.keras.utils import plot_model

import matplotlib.pyplot as plt

from tensorflow.keras.datasets import mnist 

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization

# %%
#loading the MNIST Dataset 

(X_train, y_train), (X_test,y_test) = mnist.load_data()

# %%
#printing the shapes 

print(X_train.shape, y_train.shape)

print(X_test.shape , y_test.shape)

# %%
#printing the shapes 

print(X_train.shape,y_train.shape)

print(X_test.shape , y_test.shape)

# %%
X_train[0]

# %%
y_train[0]

# %% [markdown]
# # Normaliziation

# %%
X_train/255
y_train/255

# %%
X_train[0]

# %%
y_train[0]
# Out:
# 5

# %%
#plotting images of dataset 

fig = plt.figure(figsize = (10,3))

for i in range(20):

    ax= fig.add_subplot(2, 10, i+1, xticks=[], yticks=[])

    ax.imshow(np.squeeze(X_train[i]), cmap='gray')

    ax.set_title(y_train[i])

# %%
#reshaping train and test sets 

train_x = train_x.reshape((train_x.shape[0], train_x.shape[1], train_x.shape[2], 1))

test_x = test_x .reshape((test_x.shape[0], test_x.shape[1], test_x.shape[2], 1))

# %% [markdown]
# ## with using different activation functions

# %%
#with using relu and softmax activation function
model1 = keras.models.Sequential([
                         keras.layers.Flatten(input_shape=[28,28]),
                         keras.layers.Dense(units=32, activation='relu'),
                         keras.layers.Dense(units=10, activation='softmax'),
])

# %% [markdown]
# ## complie model with different optimizers

# %%
#complie model with different optimizer [adam]

model1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#Train the model
history=model1.fit(X_train,y_train,epochs=10,validation_split=0.20, 
    batch_size=20, 
    verbose=2)
# Out:
# Epoch 1/10
# 2400/2400 - 11s - loss: 2.2056 - accuracy: 0.6016 - val_loss: 0.8999 - val_accuracy: 0.7828 - 11s/epoch - 5ms/step
# Epoch 2/10
# 2400/2400 - 8s - loss: 0.7267 - accuracy: 0.8021 - val_loss: 0.6335 - val_accuracy: 0.8482 - 8s/epoch - 3ms/step
# Epoch 3/10
# 2400/2400 - 9s - loss: 0.5114 - accuracy: 0.8679 - val_loss: 0.4902 - val_accuracy: 0.8821 - 9s/epoch - 4ms/step
# Epoch 4/10
# 2400/2400 - 8s - loss: 0.4248 - accuracy: 0.8919 - val_loss: 0.4386 - val_accuracy: 0.8913 - 8s/epoch - 3ms/step
# Epoch 5/10
# 2400/2400 - 8s - loss: 0.3805 - accuracy: 0.9033 - val_loss: 0.3990 - val_accuracy: 0.9019 - 8s/epoch - 3ms/step
# Epoch 6/10
# 2400/2400 - 8s - loss: 0.3550 - accuracy: 0.9094 - val_loss: 0.3510 - val_accuracy: 0.9122 - 8s/epoch - 3ms/step
# Epoch 7/10
# 2400/2400 - 8s - loss: 0.3407 - accuracy: 0.9128 - val_loss: 0.3375 - val_accuracy: 0.9173 - 8s/epoch - 3ms/step
# Epoch 8/10
# ...

# %%
#using sigmoid and soft max
model2= keras.models.Sequential([
                         keras.layers.Flatten(input_shape=[28,28]),
                         keras.layers.Dense(units=32, activation='sigmoid'),
                         keras.layers.Dense(units=10, activation='softmax'),
])

# %%
#compile with[nadam]
model2.compile(optimizer='Nadam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#Train the model
history2=model2.fit(X_train,y_train,epochs=10,validation_split=0.20, 
    batch_size=20, 
    verbose=2)
# Out:
# Epoch 1/10
# 2400/2400 - 11s - loss: 0.8040 - accuracy: 0.7810 - val_loss: 0.4900 - val_accuracy: 0.8653 - 11s/epoch - 4ms/step
# Epoch 2/10
# 2400/2400 - 9s - loss: 0.4782 - accuracy: 0.8586 - val_loss: 0.4167 - val_accuracy: 0.8793 - 9s/epoch - 4ms/step
# Epoch 3/10
# 2400/2400 - 9s - loss: 0.4358 - accuracy: 0.8691 - val_loss: 0.3759 - val_accuracy: 0.8856 - 9s/epoch - 4ms/step
# Epoch 4/10
# 2400/2400 - 9s - loss: 0.4001 - accuracy: 0.8788 - val_loss: 0.3815 - val_accuracy: 0.8849 - 9s/epoch - 4ms/step
# Epoch 5/10
# 2400/2400 - 9s - loss: 0.3814 - accuracy: 0.8846 - val_loss: 0.3700 - val_accuracy: 0.8867 - 9s/epoch - 4ms/step
# Epoch 6/10
# 2400/2400 - 9s - loss: 0.3718 - accuracy: 0.8898 - val_loss: 0.3423 - val_accuracy: 0.8981 - 9s/epoch - 4ms/step
# Epoch 7/10
# 2400/2400 - 9s - loss: 0.3715 - accuracy: 0.8865 - val_loss: 0.3447 - val_accuracy: 0.8927 - 9s/epoch - 4ms/step
# Epoch 8/10
# ...

# %%
#using tanh  and soft max
model3= keras.models.Sequential([
                         keras.layers.Flatten(input_shape=[28,28]),
                         keras.layers.Dense(units=32, activation='tanh'),
                         keras.layers.Dense(units=10, activation='softmax'),
])

# %%
#compile with [Adagrad]
model3.compile(optimizer='Adagrad', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#Train the model
history2=model2.fit(X_train,y_train,epochs=10,validation_split=0.20, 
    batch_size=20, 
    verbose=2)
# Out:
# Epoch 1/10
# 2400/2400 - 8s - loss: 0.3351 - accuracy: 0.8981 - val_loss: 0.3075 - val_accuracy: 0.9082 - 8s/epoch - 3ms/step
# Epoch 2/10
# 2400/2400 - 8s - loss: 0.3258 - accuracy: 0.9024 - val_loss: 0.3110 - val_accuracy: 0.9078 - 8s/epoch - 3ms/step
# Epoch 3/10
# 2400/2400 - 9s - loss: 0.3279 - accuracy: 0.9012 - val_loss: 0.3156 - val_accuracy: 0.9093 - 9s/epoch - 4ms/step
# Epoch 4/10
# 2400/2400 - 9s - loss: 0.3154 - accuracy: 0.9057 - val_loss: 0.3113 - val_accuracy: 0.9062 - 9s/epoch - 4ms/step
# Epoch 5/10
# 2400/2400 - 9s - loss: 0.3016 - accuracy: 0.9115 - val_loss: 0.2817 - val_accuracy: 0.9170 - 9s/epoch - 4ms/step
# Epoch 6/10
# 2400/2400 - 9s - loss: 0.2972 - accuracy: 0.9118 - val_loss: 0.3102 - val_accuracy: 0.9096 - 9s/epoch - 4ms/step
# Epoch 7/10
# 2400/2400 - 9s - loss: 0.3120 - accuracy: 0.9070 - val_loss: 0.2851 - val_accuracy: 0.9160 - 9s/epoch - 4ms/step
# Epoch 8/10
# ...

# %%
#using  Leaky ReLU and soft max
model3= keras.models.Sequential([
                         keras.layers.Flatten(input_shape=[28,28]),
                         keras.layers.Dense(units=32, activation='LeakyReLU'),
                         keras.layers.Dense(units=10, activation='softmax'),
])

# %%
#compile with[Adadelta]
model3.compile(optimizer='Adadelta', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#Train the model
history3=model2.fit(X_train,y_train,epochs=10,validation_split=0.20, 
    batch_size=20, 
    verbose=2)
# Out:
# Epoch 1/10
# 2400/2400 - 8s - loss: 0.2881 - accuracy: 0.9132 - val_loss: 0.2928 - val_accuracy: 0.9143 - 8s/epoch - 3ms/step
# Epoch 2/10
# 2400/2400 - 9s - loss: 0.2941 - accuracy: 0.9131 - val_loss: 0.3094 - val_accuracy: 0.9072 - 9s/epoch - 4ms/step
# Epoch 3/10
# 2400/2400 - 8s - loss: 0.2974 - accuracy: 0.9109 - val_loss: 0.2883 - val_accuracy: 0.9153 - 8s/epoch - 3ms/step
# Epoch 4/10
# 2400/2400 - 8s - loss: 0.2881 - accuracy: 0.9148 - val_loss: 0.2809 - val_accuracy: 0.9171 - 8s/epoch - 3ms/step
# Epoch 5/10
# 2400/2400 - 9s - loss: 0.2786 - accuracy: 0.9170 - val_loss: 0.2809 - val_accuracy: 0.9164 - 9s/epoch - 4ms/step
# Epoch 6/10
# 2400/2400 - 9s - loss: 0.2861 - accuracy: 0.9143 - val_loss: 0.2787 - val_accuracy: 0.9169 - 9s/epoch - 4ms/step
# Epoch 7/10
# 2400/2400 - 9s - loss: 0.2856 - accuracy: 0.9128 - val_loss: 0.2900 - val_accuracy: 0.9141 - 9s/epoch - 4ms/step
# Epoch 8/10
# ...

# %%
#using tanh  and soft max
model4= keras.models.Sequential([
                         keras.layers.Flatten(input_shape=[28,28]),
                         keras.layers.Dense(units=32, activation='tanh'),
                         keras.layers.Dense(units=10, activation='softmax'),
])

# %%
#compile with RMSProp
model4.compile(optimizer='RMSProp', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#Train the model
history4=model2.fit(X_train,y_train,epochs=10,validation_split=0.20, 
    batch_size=20, 
    verbose=2)
# Out:
# Epoch 1/10
# 2400/2400 - 10s - loss: 0.2796 - accuracy: 0.9171 - val_loss: 0.2862 - val_accuracy: 0.9118 - 10s/epoch - 4ms/step
# Epoch 2/10
# 2400/2400 - 9s - loss: 0.2637 - accuracy: 0.9216 - val_loss: 0.2561 - val_accuracy: 0.9260 - 9s/epoch - 4ms/step
# Epoch 3/10
# 2400/2400 - 9s - loss: 0.2661 - accuracy: 0.9206 - val_loss: 0.2638 - val_accuracy: 0.9227 - 9s/epoch - 4ms/step
# Epoch 4/10
# 2400/2400 - 9s - loss: 0.2649 - accuracy: 0.9204 - val_loss: 0.2762 - val_accuracy: 0.9186 - 9s/epoch - 4ms/step
# Epoch 5/10
# 2400/2400 - 9s - loss: 0.2735 - accuracy: 0.9187 - val_loss: 0.2775 - val_accuracy: 0.9194 - 9s/epoch - 4ms/step
# Epoch 6/10
# 2400/2400 - 10s - loss: 0.2778 - accuracy: 0.9175 - val_loss: 0.2771 - val_accuracy: 0.9197 - 10s/epoch - 4ms/step
# Epoch 7/10
# 2400/2400 - 9s - loss: 0.2894 - accuracy: 0.9114 - val_loss: 0.2953 - val_accuracy: 0.9127 - 9s/epoch - 4ms/step
# Epoch 8/10
# ...

# %%
#using linear and soft max
model5= keras.models.Sequential([
                         keras.layers.Flatten(input_shape=[28,28]),
                         keras.layers.Dense(units=32, activation='linear'),
                         keras.layers.Dense(units=10, activation='softmax'),
])

# %%
#compile with SGD
model5.compile(optimizer='SGD', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#Train the model
history5=model2.fit(X_train,y_train,epochs=10,validation_split=0.20, 
    batch_size=20, 
    verbose=2)
# Out:
# Epoch 1/10
# 2400/2400 - 9s - loss: 0.2626 - accuracy: 0.9217 - val_loss: 0.2693 - val_accuracy: 0.9227 - 9s/epoch - 4ms/step
# Epoch 2/10
# 2400/2400 - 9s - loss: 0.2608 - accuracy: 0.9226 - val_loss: 0.2536 - val_accuracy: 0.9251 - 9s/epoch - 4ms/step
# Epoch 3/10
# 2400/2400 - 10s - loss: 0.2624 - accuracy: 0.9200 - val_loss: 0.2576 - val_accuracy: 0.9251 - 10s/epoch - 4ms/step
# Epoch 4/10
# 2400/2400 - 10s - loss: 0.2475 - accuracy: 0.9260 - val_loss: 0.2465 - val_accuracy: 0.9277 - 10s/epoch - 4ms/step
# Epoch 5/10
# 2400/2400 - 9s - loss: 0.2394 - accuracy: 0.9286 - val_loss: 0.2563 - val_accuracy: 0.9277 - 9s/epoch - 4ms/step
# Epoch 6/10
# 2400/2400 - 10s - loss: 0.2407 - accuracy: 0.9281 - val_loss: 0.2463 - val_accuracy: 0.9302 - 10s/epoch - 4ms/step
# Epoch 7/10
# 2400/2400 - 9s - loss: 0.2354 - accuracy: 0.9302 - val_loss: 0.2424 - val_accuracy: 0.9286 - 9s/epoch - 4ms/step
# Epoch 8/10
# ...

# %%
#using linear and soft max
model5= keras.models.Sequential([
                         keras.layers.Flatten(input_shape=[28,28]),
                         keras.layers.Dense(units=32, activation='ELU'),
                         keras.layers.Dense(units=10, activation='softmax'),
])

# %%
#compile with[Adadelta]
model5.compile(optimizer='Adadelta', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#Train the model
history5=model2.fit(X_train,y_train,epochs=10,validation_split=0.20, 
    batch_size=20, 
    verbose=2)
# Out:
# Epoch 1/10
# 2400/2400 - 9s - loss: 0.2390 - accuracy: 0.9288 - val_loss: 0.2471 - val_accuracy: 0.9277 - 9s/epoch - 4ms/step
# Epoch 2/10
# 2400/2400 - 9s - loss: 0.2435 - accuracy: 0.9285 - val_loss: 0.2443 - val_accuracy: 0.9298 - 9s/epoch - 4ms/step
# Epoch 3/10
# 2400/2400 - 9s - loss: 0.2496 - accuracy: 0.9263 - val_loss: 0.2726 - val_accuracy: 0.9189 - 9s/epoch - 4ms/step
# Epoch 4/10
# 2400/2400 - 9s - loss: 0.2504 - accuracy: 0.9247 - val_loss: 0.2426 - val_accuracy: 0.9308 - 9s/epoch - 4ms/step
# Epoch 5/10
# 2400/2400 - 9s - loss: 0.2519 - accuracy: 0.9253 - val_loss: 0.2541 - val_accuracy: 0.9268 - 9s/epoch - 4ms/step
# Epoch 6/10
# 2400/2400 - 10s - loss: 0.2419 - accuracy: 0.9280 - val_loss: 0.2484 - val_accuracy: 0.9301 - 10s/epoch - 4ms/step
# Epoch 7/10
# 2400/2400 - 9s - loss: 0.2439 - accuracy: 0.9271 - val_loss: 0.2629 - val_accuracy: 0.9222 - 9s/epoch - 4ms/step
# Epoch 8/10
# ...

# %% [markdown]
# ## using Dropout and Earlystopping

# %%
#using linear and soft max
model6= keras.models.Sequential([
                         keras.layers.Flatten(input_shape=[28,28]),Dropout(0.25),
                         keras.layers.Dense(units=32, activation='sigmoid'),
                         keras.layers.Dense(units=10, activation='softmax'),
])

# %%
#compile with[Adadelta]
model6.compile(optimizer='Adadelta', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#Train the model
history6=model2.fit(X_train,y_train,epochs=10,validation_split=0.20, 
    batch_size=20, 
    verbose=2)
# Out:
# Epoch 1/10
# 2400/2400 - 10s - loss: 0.2290 - accuracy: 0.9314 - val_loss: 0.2375 - val_accuracy: 0.9293 - 10s/epoch - 4ms/step
# Epoch 2/10
# 2400/2400 - 10s - loss: 0.2240 - accuracy: 0.9326 - val_loss: 0.2473 - val_accuracy: 0.9264 - 10s/epoch - 4ms/step
# Epoch 3/10
# 2400/2400 - 9s - loss: 0.2328 - accuracy: 0.9302 - val_loss: 0.2389 - val_accuracy: 0.9309 - 9s/epoch - 4ms/step
# Epoch 4/10
# 2400/2400 - 10s - loss: 0.2269 - accuracy: 0.9332 - val_loss: 0.2323 - val_accuracy: 0.9323 - 10s/epoch - 4ms/step
# Epoch 5/10
# 2400/2400 - 9s - loss: 0.2286 - accuracy: 0.9324 - val_loss: 0.2448 - val_accuracy: 0.9309 - 9s/epoch - 4ms/step
# Epoch 6/10
# 2400/2400 - 9s - loss: 0.2320 - accuracy: 0.9310 - val_loss: 0.2394 - val_accuracy: 0.9288 - 9s/epoch - 4ms/step
# Epoch 7/10
# 2400/2400 - 9s - loss: 0.2392 - accuracy: 0.9285 - val_loss: 0.2492 - val_accuracy: 0.9279 - 9s/epoch - 4ms/step
# Epoch 8/10
# ...

# %%
#using linear and soft max
model7= keras.models.Sequential([
                         keras.layers.Flatten(input_shape=[28,28]),
                         keras.layers.Dense(units=32, activation='sigmoid'),
                         keras.layers.Dense(units=10, activation='softmax'),
])

# %%
#compile with[Adadelta]
model7.compile(optimizer='Adadelta', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping
callsbacks=[EarlyStopping(monitor="val_accuracy",patience=3)]
history7 =model7.fit(X_train,y_train,epochs=5,batch_size=2,validation_split=0)
# Out:
# Epoch 1/5
# 30000/30000 [==============================] - 100s 3ms/step - loss: 2.6472 - accuracy: 0.1114
# Epoch 2/5
# 30000/30000 [==============================] - 101s 3ms/step - loss: 2.5587 - accuracy: 0.1196
# Epoch 3/5
# 30000/30000 [==============================] - 101s 3ms/step - loss: 2.4813 - accuracy: 0.1292
# Epoch 4/5
# 30000/30000 [==============================] - 105s 3ms/step - loss: 2.4125 - accuracy: 0.1396
# Epoch 5/5
# 30000/30000 [==============================] - 105s 3ms/step - loss: 2.3510 - accuracy: 0.1511

# %% [markdown]
# # analysis their performance

# %% [markdown]
# ## plot loss of different optimizer

# %%
#plot loss of different optimizer 
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']
loss = history2.history['loss']
val_loss = history2.history['val_loss']
epochs_range = range(len(acc))
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

acc = history3.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history3.history['loss']
val_loss = history3.history['val_loss']
epochs_range = range(len(acc))
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 3)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()


acc = history4.history['accuracy']
val_acc = history4.history['val_accuracy']
loss = history4.history['loss']
val_loss = history4.history['val_loss']
epochs_range = range(len(acc))
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 4)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()



acc = history5.history['accuracy']
val_acc = history5.history['val_accuracy']
loss = history5.history['loss']
val_loss = history5.history['val_loss']
epochs_range = range(len(acc))
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 5)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()


acc = history6.history['accuracy']
val_acc = history6.history['val_accuracy']
loss = history6.history['loss']
val_loss = history6.history['val_loss']
epochs_range = range(len(acc))
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 6)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

acc = history7.history['accuracy']
val_acc = history7.history['val_accuracy']
loss = history7.history['loss']
val_loss = history6.history['val_loss']
epochs_range = range(len(acc))
plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 7)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# As we can see that by performing models only model with activation function [sigmoid nd softmax ]and optimizer function [adelta] is given 92% accuarcy and with dropout also
#  model 4 is best for the minst dataset for DNN
